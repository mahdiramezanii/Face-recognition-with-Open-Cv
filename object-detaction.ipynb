# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread("./images/webcam_image-2XBZ8.PNG")

# %%
cv2.imshow("Navid",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#load cascade clasifier

# %%
face_cascade=cv2.CascadeClassifier("./heer-algoritm/haarcascade_frontalface_default.xml")

# %%
#aply cascade calssfire to on image

# %%
face,number_of_detaction=face_cascade.detectMultiScale2(image,minNeighbors=8)

# %%
print(face)
# Out:
# [[281 159 196 196]]

# %%
print(number_of_detaction)
# Out:
# [64]

# %%
for x,y,h,w in face:
    
    cv2.rectangle(image,(x,y),(x+h,y+w),(132,190,144),2)

# %%
cv2.imshow("esl",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(image[:,:,[2,1,0]])
plt.show()
